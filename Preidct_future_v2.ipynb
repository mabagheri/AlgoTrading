# %%
import json
import time
import random
import numpy as np
import pandas as pd
import xgboost as xgb
import datetime
# import pandas as pd
from core.initialization.load_data_file_paths import load_selected_data_files_paths
# from core.classification.learning_utils import encode_categorical_labels_to_numerical
# from core.classification.main import classify
from core.feature_extraction.FE_v0 import load_preprocess_extract_features
import warnings
warnings.filterwarnings("ignore")
np.random.seed(135)
random.seed(135)
pd.set_option("display.max_cols", None)

def get_predictions(model_folder, start_day, end_day):
    configs = json.load(open('Results/' + model_folder + '/configs.json', 'r'))
    configs["data_selection"]["time_filtering"] = [start_day, end_day]
    performances = pd.read_csv("Results/" + model_folder + '/performances.csv')
    precision_1_test = performances.iloc[1, 4]
    # 1:
    ""
    data_paths, metadata = load_selected_data_files_paths(configs)

    # 2: Get Xy for prediction (future)
    Xy = load_preprocess_extract_features(data_paths, metadata, configs)
    print("Xy.shape", Xy.shape)

    samples_for_prediction = Xy[Xy['Label'].isnull()]
    y_samples_for_prediction = samples_for_prediction['Label']
    cols_not_for_training = ["Ticker", 'Date', 'close', 'open', 'high', 'low', 'volume', 'Label', 'Max_increase', 
                             'Max_decrease']
    X_samples_for_prediction = samples_for_prediction.drop(cols_not_for_training, axis=1)

    print("X_samples_for_prediction", X_samples_for_prediction.shape)

    # 3:
    model = xgb.Booster()  # init model
    model.load_model('Results/' + model_folder + '/model_sklearn.json')  # load data

    d_test = xgb.DMatrix(X_samples_for_prediction, label=y_samples_for_prediction, nthread=2)

    prob_y_test = model.predict(d_test)
    result_fold_ts = samples_for_prediction[['Ticker', 'Date']]
    result_fold_ts[model_folder] = prob_y_test

    # n =2
    # import shap
    # import matplotlib.pyplot as plt
    # top_n_predictions = result_fold_ts[model_folder].nlargest(n).reset_index()['index'].values
    # X_top_n = X_samples_for_prediction.loc[top_n_predictions]
    # for x in top_n_predictions:
    #     explainer = shap.Explainer(model)
    #     shap_values = explainer(X_top_n)
    #     shap.plots.force(shap_values[0])
    #     plt.show()

    # configs = json.load(open(model_folder + '/configs.json', 'r'))
    # first_day = samples_for_prediction['Date'].min().strftime("%Y%m%d")
    # last_day = samples_for_prediction['Date'].max().strftime("%Y%m%d")
    # Market = str(configs['data_selection']['ticker_filtering']['Country'][0])
    # m_caps = configs['data_selection']['ticker_filtering']['MarketCap_in_Billion']

    # result_fold_ts.to_csv(f'Results/Future_prediction/{first_day}_to_{last_day}_{Market}_{m_caps[0]}_{m_caps[1]}B.csv', 
    # index=False)

    # result_fold_ts = pd.concat([X_test[cols_not_for_training].reset_index(drop=True),
    #                             result_fold_ts.reset_index(drop=True)], axis=1)
    return pd.DataFrame(result_fold_ts), precision_1_test
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# <ipython-input-65-ee2d4f491557> in <module>
#      15 np.random.seed(135)
#      16 random.seed(135)
# ---> 17 pd.set_option("display.max_cols", None)
#      18
#      19 def get_predictions(model_folder, start_day, end_day):
#
# ~\Anaconda3\lib\site-packages\pandas\_config\config.py in __call__(self, *args, **kwds)
#     231
#     232     def __call__(self, *args, **kwds):
# --> 233         return self.__func__(*args, **kwds)
#     234
#     235     @property
#
# ~\Anaconda3\lib\site-packages\pandas\_config\config.py in _set_option(*args, **kwargs)
#     124
#     125     for k, v in zip(args[::2], args[1::2]):
# --> 126         key = _get_single_key(k, silent)
#     127
#     128         o = _get_registered_option(key)
#
# ~\Anaconda3\lib\site-packages\pandas\_config\config.py in _get_single_key(pat, silent)
#      89         if not silent:
#      90             _warn_if_deprecated(pat)
# ---> 91         raise OptionError(f"No such keys(s): {repr(pat)}")
#      92     if len(keys) > 1:
#      93         raise OptionError("Pattern matched multiple keys")
#
# OptionError: "No such keys(s): 'display.max_cols'"

# %%
st = time.time()

today = datetime.datetime.today().strftime('%Y-%m-%d')
end_date = today
start_date = str(datetime.date.today() + datetime.timedelta(days=-15))  # "2022-02-03"
print(start_date, end_date)

models = [
    ['Jan2022/2022.02.01-1153_All_10_3000B_20210101_to_20220131, 5_in_5days', start_date, end_date],
    ['Jan2022/2022.02.01-1203_All_30_3000B_20210101_to_20220131, 5_in_5days', start_date, end_date],
    ['Jan2022/+2022.01.30-2245_All_40_3000B_20210101_to_20220128, 7_in_14days', start_date, end_date],
    ['Jan2022/+2022.01.30-2356_All_40_3000B_20210101_to_20220128, 5_in_10days', start_date, end_date],
    ['Jan2022/+2022.01.31-2246_All_10_3000B_20210101_to_20220131, 5_in_10days', start_date, end_date],
    ['Jan2022/+2022.01.31-2256_All_10_3000B_20210501_to_20211231, 7_in_14days', start_date, end_date],
    ['Jan2022/2022.01.31-2305_All_10_3000B_20210101_to_20220131, 7_in_14days',  start_date, end_date],
    ['2022.03.02-1516_Canada_All_30_3000B_20210101_to_20220228, 5_in_10days', start_date, end_date],
    ['2022.03.02-1514_Canada_All_30_3000B_20210101_to_20220228, 4_in_4days', start_date, end_date],
    ['2022.03.02-1505_Canada_All_5_3000B_20210101_to_20220228, 4_in_4days', start_date, end_date],
    ['2022.03.02-1500_Canada_All_5_3000B_20210101_to_20220228, 7_in_14days', start_date, end_date],
    # ['',  start_date, end_date],
    ]

res, Precision_1_test = get_predictions(models[0][0], models[0][1], models[0][2])
classifiers_weights = [Precision_1_test]

for model_folder1, from_date, to_date in models[1:]:
    print(f"\n {model_folder1}")
    res1, Precision_1_test = get_predictions(model_folder1, from_date, to_date)
    res = pd.merge(res, res1, how='outer', on=['Ticker', 'Date'])
    classifiers_weights.append(Precision_1_test)

res['Weighted Avg'] = np.average(res.iloc[:, 2:2+len(models)], axis=1, weights=classifiers_weights)
res['Mean'] = np.mean(res.iloc[:, 2:2+len(models)], axis=1)
res['Prod'] = np.prod(res.iloc[:, 2:2+len(models)], axis=1)

now = time.strftime('%Y.%m.%d-%H%M')
res.to_csv(f'Results/+ Future_prediction/{now}.csv', index=False)

print(classifiers_weights)
print("Elapsed time (seconds) : ", (time.time() - st)/60)
# Out:
# 2022-03-08 2022-03-23
# selected_meta_data.shape =  (83, 13)
# Finance                   16
# Non-Energy Minerals       13
# Retail Trade               8
# Technology Services        7
# Communications             6
# Utilities                  6
# Industrial Services        6
# Energy Minerals            6
# Consumer Non-Durables      4
# Transportation             3
# Commercial Services        3
# Consumer Services          2
# Health Technology          1
# Producer Manufacturing     1
# Process Industries         1
# Name: Sector, dtype: int64
# Processing 1 / 83: 	 ABX.to
# Duplicated column names [] []
# Processing 2 / 83: 	 AEM.to
# Processing 3 / 83: 	 AQN.to
# Processing 4 / 83: 	 ATD.to
# Processing 5 / 83: 	 BAM-A.to
# Processing 6 / 83: 	 BCE.to
# Processing 7 / 83: 	 BEP-UN.to
# Processing 8 / 83: 	 BHC.to
# Processing 9 / 83: 	 BIP-UN.to
# Processing 10 / 83: 	 BMO.to
# Processing 11 / 83: 	 BNS.to
# Processing 12 / 83: 	 CAE.to
# Processing 13 / 83: 	 CCL-A.to
# Processing 14 / 83: 	 CCL-B.to
# Processing 15 / 83: 	 CCO.to
# Processing 16 / 83: 	 CDAY.to
# Processing 17 / 83: 	 CM.to
# Processing 18 / 83: 	 CNQ.to
# Processing 19 / 83: 	 CNR.to
# Processing 20 / 83: 	 CP.to
# Processing 21 / 83: 	 CSU.to
# Processing 22 / 83: 	 CTC-A.to
# Processing 23 / 83: 	 CTC.to
# Processing 24 / 83: 	 CVE.to
# Processing 25 / 83: 	 DOL.to
# Processing 26 / 83: 	 EMA.to
# Processing 27 / 83: 	 EMP-A.to
# Processing 28 / 83: 	 ENB.to
# Processing 29 / 83: 	 FFH-U.to
# Short history of ticker, Skip it !
# Processing 30 / 83: 	 FFH.to
# Processing 31 / 83: 	 FM.to
# Processing 32 / 83: 	 FNV.to
# Processing 33 / 83: 	 FSV.to
# Processing 34 / 83: 	 FTS.to
# Processing 35 / 83: 	 GFL.to
# Processing 36 / 83: 	 GIB-A.to
# Processing 37 / 83: 	 GIL.to
# Processing 38 / 83: 	 GWO.to
# Processing 39 / 83: 	 H.to
# Processing 40 / 83: 	 IFC.to
# Processing 41 / 83: 	 IGM.to
# Processing 42 / 83: 	 IMO.to
# Processing 43 / 83: 	 IVN.to
# Processing 44 / 83: 	 KL.to
# Processing 45 / 83: 	 L.to
# Processing 46 / 83: 	 MFC.to
# Processing 47 / 83: 	 MG.to
# Processing 48 / 83: 	 MRU.to
# Processing 49 / 83: 	 NA.to
# Processing 50 / 83: 	 NCM.to
# Processing 51 / 83: 	 NGT.to
# Processing 52 / 83: 	 NTR.to
# Processing 53 / 83: 	 NVEI.to
# Processing 54 / 83: 	 OTEX.to
# Processing 55 / 83: 	 OVV.to
# Processing 56 / 83: 	 POW.to
# Processing 57 / 83: 	 PPL.to
# Processing 58 / 83: 	 QSP-UN.to
# Processing 59 / 83: 	 QSR.to
# Processing 60 / 83: 	 RCI-A.to
# Processing 61 / 83: 	 RCI-B.to
# Processing 62 / 83: 	 RY.to
# Processing 63 / 83: 	 SAP.to
# Processing 64 / 83: 	 SJR-B.to
# Processing 65 / 83: 	 SLF.to
# Processing 66 / 83: 	 SU.to
# Processing 67 / 83: 	 Shop.to
# Processing 68 / 83: 	 T.to
# Processing 69 / 83: 	 TD.to
# Processing 70 / 83: 	 TECK-A.to
# Processing 71 / 83: 	 TECK-B.to
# Processing 72 / 83: 	 TFII.to
# Processing 73 / 83: 	 TIXT.to
# Processing 74 / 83: 	 TOU.to
# Processing 75 / 83: 	 TPX-A.to
# Processing 76 / 83: 	 TPX-B.to
# Processing 77 / 83: 	 TRI.to
# Processing 78 / 83: 	 TRP.to
# Processing 79 / 83: 	 WCN.to
# Processing 80 / 83: 	 WFG.to
# Processing 81 / 83: 	 WN.to
# Processing 82 / 83: 	 WPM.to
# Processing 83 / 83: 	 WSP.to
# Whole Dataset Generated with Shape of (33757, 163)
# FinTA.OBV_Normalized column .isnull().values.any()
# FinTA.Pct_change_400 column .isnull().values.any()
# Feature extraction elapsed time (seconds) :  140.95809650421143
# Xy.shape (953, 163)
# X_samples_for_prediction (400, 153)
#
#  Jan2022/2022.02.01-1203_All_30_3000B_20210101_to_20220131, 5_in_5days
# selected_meta_data.shape =  (35, 13)
# Finance                   10
# Communications             4
# Energy Minerals            4
# Non-Energy Minerals        3
# Technology Services        3
# Industrial Services        3
# Transportation             2
# Retail Trade               2
# Consumer Services          1
# Process Industries         1
# Producer Manufacturing     1
# Utilities                  1
# Name: Sector, dtype: int64
# Processing 1 / 35: 	 ABX.to
# Duplicated column names [] []
# Processing 2 / 35: 	 ATD.to
# Processing 3 / 35: 	 BAM-A.to
# Processing 4 / 35: 	 BCE.to
# Processing 5 / 35: 	 BIP-UN.to
# Processing 6 / 35: 	 BMO.to
# Processing 7 / 35: 	 BNS.to
# Processing 8 / 35: 	 CM.to
# Processing 9 / 35: 	 CNQ.to
# Processing 10 / 35: 	 CNR.to
# Processing 11 / 35: 	 CP.to
# Processing 12 / 35: 	 CSU.to
# Processing 13 / 35: 	 CVE.to
# Processing 14 / 35: 	 ENB.to
# Processing 15 / 35: 	 FNV.to
# Processing 16 / 35: 	 GWO.to
# Processing 17 / 35: 	 IMO.to
# Processing 18 / 35: 	 L.to
# Processing 19 / 35: 	 MFC.to
# Processing 20 / 35: 	 MG.to
# Processing 21 / 35: 	 NA.to
# Processing 22 / 35: 	 NGT.to
# Processing 23 / 35: 	 NTR.to
# Processing 24 / 35: 	 QSP-UN.to
# Processing 25 / 35: 	 RCI-A.to
# Processing 26 / 35: 	 RCI-B.to
# Processing 27 / 35: 	 RY.to
# Processing 28 / 35: 	 SLF.to
# Processing 29 / 35: 	 SU.to
# Processing 30 / 35: 	 Shop.to
# Processing 31 / 35: 	 T.to
# Processing 32 / 35: 	 TD.to
# Processing 33 / 35: 	 TRI.to
# Processing 34 / 35: 	 TRP.to
# Processing 35 / 35: 	 WCN.to
# Whole Dataset Generated with Shape of (14650, 163)
# FinTA.OBV_Normalized column .isnull().values.any()
# FinTA.Pct_change_400 column .isnull().values.any()
# Feature extraction elapsed time (seconds) :  57.13073468208313
# Xy.shape (416, 163)
# X_samples_for_prediction (175, 153)
#
#  Jan2022/+2022.01.30-2245_All_40_3000B_20210101_to_20220128, 7_in_14days
# selected_meta_data.shape =  (24, 13)
# Finance                8
# Technology Services    3
# Industrial Services    3
# Non-Energy Minerals    2
# Communications         2
# Transportation         2
# Energy Minerals        2
# Retail Trade           1
# Process Industries     1
# Name: Sector, dtype: int64
# Processing 1 / 24: 	 ABX.to
# Duplicated column names [] []
# Processing 2 / 24: 	 ATD.to
# Processing 3 / 24: 	 BAM-A.to
# Processing 4 / 24: 	 BCE.to
# Processing 5 / 24: 	 BMO.to
# Processing 6 / 24: 	 BNS.to
# Processing 7 / 24: 	 CM.to
# Processing 8 / 24: 	 CNQ.to
# Processing 9 / 24: 	 CNR.to
# Processing 10 / 24: 	 CP.to
# Processing 11 / 24: 	 CSU.to
# Processing 12 / 24: 	 ENB.to
# Processing 13 / 24: 	 MFC.to
# Processing 14 / 24: 	 NGT.to
# Processing 15 / 24: 	 NTR.to
# Processing 16 / 24: 	 RY.to
# Processing 17 / 24: 	 SLF.to
# Processing 18 / 24: 	 SU.to
# Processing 19 / 24: 	 Shop.to
# Processing 20 / 24: 	 T.to
# Processing 21 / 24: 	 TD.to
# Processing 22 / 24: 	 TRI.to
# Processing 23 / 24: 	 TRP.to
# Processing 24 / 24: 	 WCN.to
# Whole Dataset Generated with Shape of (10128, 163)
# Feature extraction elapsed time (seconds) :  35.26974821090698
# Xy.shape (288, 163)
# X_samples_for_prediction (288, 153)
#
#  Jan2022/+2022.01.30-2356_All_40_3000B_20210101_to_20220128, 5_in_10days
# selected_meta_data.shape =  (24, 13)
# Finance                8
# Technology Services    3
# Industrial Services    3
# Non-Energy Minerals    2
# Communications         2
# Transportation         2
# Energy Minerals        2
# Retail Trade           1
# Process Industries     1
# Name: Sector, dtype: int64
# Processing 1 / 24: 	 ABX.to
# Duplicated column names [] []
# Processing 2 / 24: 	 ATD.to
# Processing 3 / 24: 	 BAM-A.to
# Processing 4 / 24: 	 BCE.to
# Processing 5 / 24: 	 BMO.to
# Processing 6 / 24: 	 BNS.to
# Processing 7 / 24: 	 CM.to
# Processing 8 / 24: 	 CNQ.to
# Processing 9 / 24: 	 CNR.to
# Processing 10 / 24: 	 CP.to
# Processing 11 / 24: 	 CSU.to
# Processing 12 / 24: 	 ENB.to
# Processing 13 / 24: 	 MFC.to
# Processing 14 / 24: 	 NGT.to
# Processing 15 / 24: 	 NTR.to
# Processing 16 / 24: 	 RY.to
# Processing 17 / 24: 	 SLF.to
# Processing 18 / 24: 	 SU.to
# Processing 19 / 24: 	 Shop.to
# Processing 20 / 24: 	 T.to
# Processing 21 / 24: 	 TD.to
# Processing 22 / 24: 	 TRI.to
# Processing 23 / 24: 	 TRP.to
# Processing 24 / 24: 	 WCN.to
# Whole Dataset Generated with Shape of (10128, 163)
# Feature extraction elapsed time (seconds) :  36.82884335517883
# Xy.shape (288, 163)
# X_samples_for_prediction (240, 153)
#
#  Jan2022/+2022.01.31-2246_All_10_3000B_20210101_to_20220131, 5_in_10days
# selected_meta_data.shape =  (83, 13)
# Finance                   16
# Non-Energy Minerals       13
# Retail Trade               8
# Technology Services        7
# Communications             6
# Utilities                  6
# Industrial Services        6
# Energy Minerals            6
# Consumer Non-Durables      4
# Transportation             3
# Commercial Services        3
# Consumer Services          2
# Health Technology          1
# Producer Manufacturing     1
# Process Industries         1
# Name: Sector, dtype: int64
# Processing 1 / 83: 	 ABX.to
# Duplicated column names [] []
# Processing 2 / 83: 	 AEM.to
# Processing 3 / 83: 	 AQN.to
# Processing 4 / 83: 	 ATD.to
# Processing 5 / 83: 	 BAM-A.to
# Processing 6 / 83: 	 BCE.to
# Processing 7 / 83: 	 BEP-UN.to
# Processing 8 / 83: 	 BHC.to
# Processing 9 / 83: 	 BIP-UN.to
# Processing 10 / 83: 	 BMO.to
# Processing 11 / 83: 	 BNS.to
# Processing 12 / 83: 	 CAE.to
# Processing 13 / 83: 	 CCL-A.to
# Processing 14 / 83: 	 CCL-B.to
# Processing 15 / 83: 	 CCO.to
# Processing 16 / 83: 	 CDAY.to
# Processing 17 / 83: 	 CM.to
# Processing 18 / 83: 	 CNQ.to
# Processing 19 / 83: 	 CNR.to
# Processing 20 / 83: 	 CP.to
# Processing 21 / 83: 	 CSU.to
# Processing 22 / 83: 	 CTC-A.to
# Processing 23 / 83: 	 CTC.to
# Processing 24 / 83: 	 CVE.to
# Processing 25 / 83: 	 DOL.to
# Processing 26 / 83: 	 EMA.to
# Processing 27 / 83: 	 EMP-A.to
# Processing 28 / 83: 	 ENB.to
# Processing 29 / 83: 	 FFH-U.to
# Short history of ticker, Skip it !
# Processing 30 / 83: 	 FFH.to
# Processing 31 / 83: 	 FM.to
# Processing 32 / 83: 	 FNV.to
# Processing 33 / 83: 	 FSV.to
# Processing 34 / 83: 	 FTS.to
# Processing 35 / 83: 	 GFL.to
# Processing 36 / 83: 	 GIB-A.to
# Processing 37 / 83: 	 GIL.to
# Processing 38 / 83: 	 GWO.to
# Processing 39 / 83: 	 H.to
# Processing 40 / 83: 	 IFC.to
# Processing 41 / 83: 	 IGM.to
# Processing 42 / 83: 	 IMO.to
# Processing 43 / 83: 	 IVN.to
# Processing 44 / 83: 	 KL.to
# Processing 45 / 83: 	 L.to
# Processing 46 / 83: 	 MFC.to
# Processing 47 / 83: 	 MG.to
# Processing 48 / 83: 	 MRU.to
# Processing 49 / 83: 	 NA.to
# Processing 50 / 83: 	 NCM.to
# Processing 51 / 83: 	 NGT.to
# Processing 52 / 83: 	 NTR.to
# Processing 53 / 83: 	 NVEI.to
# Processing 54 / 83: 	 OTEX.to
# Processing 55 / 83: 	 OVV.to
# Processing 56 / 83: 	 POW.to
# Processing 57 / 83: 	 PPL.to
# Processing 58 / 83: 	 QSP-UN.to
# Processing 59 / 83: 	 QSR.to
# Processing 60 / 83: 	 RCI-A.to
# Processing 61 / 83: 	 RCI-B.to
# Processing 62 / 83: 	 RY.to
# Processing 63 / 83: 	 SAP.to
# Processing 64 / 83: 	 SJR-B.to
# Processing 65 / 83: 	 SLF.to
# Processing 66 / 83: 	 SU.to
# Processing 67 / 83: 	 Shop.to
# Processing 68 / 83: 	 T.to
# Processing 69 / 83: 	 TD.to
# Processing 70 / 83: 	 TECK-A.to
# Processing 71 / 83: 	 TECK-B.to
# Processing 72 / 83: 	 TFII.to
# Processing 73 / 83: 	 TIXT.to
# Processing 74 / 83: 	 TOU.to
# Processing 75 / 83: 	 TPX-A.to
# Processing 76 / 83: 	 TPX-B.to
# Processing 77 / 83: 	 TRI.to
# Processing 78 / 83: 	 TRP.to
# Processing 79 / 83: 	 WCN.to
# Processing 80 / 83: 	 WFG.to
# Processing 81 / 83: 	 WN.to
# Processing 82 / 83: 	 WPM.to
# Processing 83 / 83: 	 WSP.to
# Whole Dataset Generated with Shape of (33757, 163)
# FinTA.OBV_Normalized column .isnull().values.any()
# FinTA.Pct_change_400 column .isnull().values.any()
# Feature extraction elapsed time (seconds) :  138.6466727256775
# Xy.shape (953, 163)
# X_samples_for_prediction (798, 153)
#
#  Jan2022/+2022.01.31-2256_All_10_3000B_20210501_to_20211231, 7_in_14days
# selected_meta_data.shape =  (83, 13)
# Finance                   16
# Non-Energy Minerals       13
# Retail Trade               8
# Technology Services        7
# Communications             6
# Utilities                  6
# Industrial Services        6
# Energy Minerals            6
# Consumer Non-Durables      4
# Transportation             3
# Commercial Services        3
# Consumer Services          2
# Health Technology          1
# Producer Manufacturing     1
# Process Industries         1
# Name: Sector, dtype: int64
# Processing 1 / 83: 	 ABX.to
# Duplicated column names [] []
# Processing 2 / 83: 	 AEM.to
# Processing 3 / 83: 	 AQN.to
# Processing 4 / 83: 	 ATD.to
# Processing 5 / 83: 	 BAM-A.to
# Processing 6 / 83: 	 BCE.to
# Processing 7 / 83: 	 BEP-UN.to
# Processing 8 / 83: 	 BHC.to
# Processing 9 / 83: 	 BIP-UN.to
# Processing 10 / 83: 	 BMO.to
# Processing 11 / 83: 	 BNS.to
# Processing 12 / 83: 	 CAE.to
# Processing 13 / 83: 	 CCL-A.to
# Processing 14 / 83: 	 CCL-B.to
# Processing 15 / 83: 	 CCO.to
# Processing 16 / 83: 	 CDAY.to
# Processing 17 / 83: 	 CM.to
# Processing 18 / 83: 	 CNQ.to
# Processing 19 / 83: 	 CNR.to
# Processing 20 / 83: 	 CP.to
# Processing 21 / 83: 	 CSU.to
# Processing 22 / 83: 	 CTC-A.to
# Processing 23 / 83: 	 CTC.to
# Processing 24 / 83: 	 CVE.to
# Processing 25 / 83: 	 DOL.to
# Processing 26 / 83: 	 EMA.to
# Processing 27 / 83: 	 EMP-A.to
# Processing 28 / 83: 	 ENB.to
# Processing 29 / 83: 	 FFH-U.to
# Short history of ticker, Skip it !
# Processing 30 / 83: 	 FFH.to
# Processing 31 / 83: 	 FM.to
# Processing 32 / 83: 	 FNV.to
# Processing 33 / 83: 	 FSV.to
# Processing 34 / 83: 	 FTS.to
# Processing 35 / 83: 	 GFL.to
# Processing 36 / 83: 	 GIB-A.to
# Processing 37 / 83: 	 GIL.to
# Processing 38 / 83: 	 GWO.to
# Processing 39 / 83: 	 H.to
# Processing 40 / 83: 	 IFC.to
# Processing 41 / 83: 	 IGM.to
# Processing 42 / 83: 	 IMO.to
# Processing 43 / 83: 	 IVN.to
# Processing 44 / 83: 	 KL.to
# Processing 45 / 83: 	 L.to
# Processing 46 / 83: 	 MFC.to
# Processing 47 / 83: 	 MG.to
# Processing 48 / 83: 	 MRU.to
# Processing 49 / 83: 	 NA.to
# Processing 50 / 83: 	 NCM.to
# Processing 51 / 83: 	 NGT.to
# Processing 52 / 83: 	 NTR.to
# Processing 53 / 83: 	 NVEI.to
# Processing 54 / 83: 	 OTEX.to
# Processing 55 / 83: 	 OVV.to
# Processing 56 / 83: 	 POW.to
# Processing 57 / 83: 	 PPL.to
# Processing 58 / 83: 	 QSP-UN.to
# Processing 59 / 83: 	 QSR.to
# Processing 60 / 83: 	 RCI-A.to
# Processing 61 / 83: 	 RCI-B.to
# Processing 62 / 83: 	 RY.to
# Processing 63 / 83: 	 SAP.to
# Processing 64 / 83: 	 SJR-B.to
# Processing 65 / 83: 	 SLF.to
# Processing 66 / 83: 	 SU.to
# Processing 67 / 83: 	 Shop.to
# Processing 68 / 83: 	 T.to
# Processing 69 / 83: 	 TD.to
# Processing 70 / 83: 	 TECK-A.to
# Processing 71 / 83: 	 TECK-B.to
# Processing 72 / 83: 	 TFII.to
# Processing 73 / 83: 	 TIXT.to
# Processing 74 / 83: 	 TOU.to
# Processing 75 / 83: 	 TPX-A.to
# Processing 76 / 83: 	 TPX-B.to
# Processing 77 / 83: 	 TRI.to
# Processing 78 / 83: 	 TRP.to
# Processing 79 / 83: 	 WCN.to
# Processing 80 / 83: 	 WFG.to
# Processing 81 / 83: 	 WN.to
# Processing 82 / 83: 	 WPM.to
# Processing 83 / 83: 	 WSP.to
# Whole Dataset Generated with Shape of (33757, 163)
# FinTA.OBV_Normalized column .isnull().values.any()
# FinTA.Pct_change_400 column .isnull().values.any()
# Feature extraction elapsed time (seconds) :  130.01373052597046
# Xy.shape (953, 163)
# X_samples_for_prediction (953, 153)
#
#  Jan2022/2022.01.31-2305_All_10_3000B_20210101_to_20220131, 7_in_14days
# selected_meta_data.shape =  (83, 13)
# Finance                   16
# Non-Energy Minerals       13
# Retail Trade               8
# Technology Services        7
# Communications             6
# Utilities                  6
# Industrial Services        6
# Energy Minerals            6
# Consumer Non-Durables      4
# Transportation             3
# Commercial Services        3
# Consumer Services          2
# Health Technology          1
# Producer Manufacturing     1
# Process Industries         1
# Name: Sector, dtype: int64
# Processing 1 / 83: 	 ABX.to
# Duplicated column names [] []
# Processing 2 / 83: 	 AEM.to
# Processing 3 / 83: 	 AQN.to
# Processing 4 / 83: 	 ATD.to
# Processing 5 / 83: 	 BAM-A.to
# Processing 6 / 83: 	 BCE.to
# Processing 7 / 83: 	 BEP-UN.to
# Processing 8 / 83: 	 BHC.to
# Processing 9 / 83: 	 BIP-UN.to
# Processing 10 / 83: 	 BMO.to
# Processing 11 / 83: 	 BNS.to
# Processing 12 / 83: 	 CAE.to
# Processing 13 / 83: 	 CCL-A.to
# Processing 14 / 83: 	 CCL-B.to
# Processing 15 / 83: 	 CCO.to
# Processing 16 / 83: 	 CDAY.to
# Processing 17 / 83: 	 CM.to
# Processing 18 / 83: 	 CNQ.to
# Processing 19 / 83: 	 CNR.to
# Processing 20 / 83: 	 CP.to
# Processing 21 / 83: 	 CSU.to
# Processing 22 / 83: 	 CTC-A.to
# Processing 23 / 83: 	 CTC.to
# Processing 24 / 83: 	 CVE.to
# Processing 25 / 83: 	 DOL.to
# Processing 26 / 83: 	 EMA.to
# Processing 27 / 83: 	 EMP-A.to
# Processing 28 / 83: 	 ENB.to
# Processing 29 / 83: 	 FFH-U.to
# Short history of ticker, Skip it !
# Processing 30 / 83: 	 FFH.to
# Processing 31 / 83: 	 FM.to
# Processing 32 / 83: 	 FNV.to
# Processing 33 / 83: 	 FSV.to
# Processing 34 / 83: 	 FTS.to
# Processing 35 / 83: 	 GFL.to
# Processing 36 / 83: 	 GIB-A.to
# Processing 37 / 83: 	 GIL.to
# Processing 38 / 83: 	 GWO.to
# Processing 39 / 83: 	 H.to
# Processing 40 / 83: 	 IFC.to
# Processing 41 / 83: 	 IGM.to
# Processing 42 / 83: 	 IMO.to
# Processing 43 / 83: 	 IVN.to
# Processing 44 / 83: 	 KL.to
# Processing 45 / 83: 	 L.to
# Processing 46 / 83: 	 MFC.to
# Processing 47 / 83: 	 MG.to
# Processing 48 / 83: 	 MRU.to
# Processing 49 / 83: 	 NA.to
# Processing 50 / 83: 	 NCM.to
# Processing 51 / 83: 	 NGT.to
# Processing 52 / 83: 	 NTR.to
# Processing 53 / 83: 	 NVEI.to
# Processing 54 / 83: 	 OTEX.to
# Processing 55 / 83: 	 OVV.to
# Processing 56 / 83: 	 POW.to
# Processing 57 / 83: 	 PPL.to
# Processing 58 / 83: 	 QSP-UN.to
# Processing 59 / 83: 	 QSR.to
# Processing 60 / 83: 	 RCI-A.to
# Processing 61 / 83: 	 RCI-B.to
# Processing 62 / 83: 	 RY.to
# Processing 63 / 83: 	 SAP.to
# Processing 64 / 83: 	 SJR-B.to
# Processing 65 / 83: 	 SLF.to
# Processing 66 / 83: 	 SU.to
# Processing 67 / 83: 	 Shop.to
# Processing 68 / 83: 	 T.to
# Processing 69 / 83: 	 TD.to
# Processing 70 / 83: 	 TECK-A.to
# Processing 71 / 83: 	 TECK-B.to
# Processing 72 / 83: 	 TFII.to
# Processing 73 / 83: 	 TIXT.to
# Processing 74 / 83: 	 TOU.to
# Processing 75 / 83: 	 TPX-A.to
# Processing 76 / 83: 	 TPX-B.to
# Processing 77 / 83: 	 TRI.to
# Processing 78 / 83: 	 TRP.to
# Processing 79 / 83: 	 WCN.to
# Processing 80 / 83: 	 WFG.to
# Processing 81 / 83: 	 WN.to
# Processing 82 / 83: 	 WPM.to
# Processing 83 / 83: 	 WSP.to
# Whole Dataset Generated with Shape of (33757, 163)
# FinTA.OBV_Normalized column .isnull().values.any()
# FinTA.Pct_change_400 column .isnull().values.any()
# Feature extraction elapsed time (seconds) :  126.08399772644043
# Xy.shape (953, 163)
# X_samples_for_prediction (953, 153)
#
#  2022.03.02-1516_Canada_All_30_3000B_20210101_to_20220228, 5_in_10days
# selected_meta_data.shape =  (35, 13)
# Finance                   10
# Communications             4
# Energy Minerals            4
# Non-Energy Minerals        3
# Technology Services        3
# Industrial Services        3
# Transportation             2
# Retail Trade               2
# Consumer Services          1
# Process Industries         1
# Producer Manufacturing     1
# Utilities                  1
# Name: Sector, dtype: int64
# Processing 1 / 35: 	 ABX.to
# Duplicated column names [] []
# Processing 2 / 35: 	 ATD.to
# Processing 3 / 35: 	 BAM-A.to
# Processing 4 / 35: 	 BCE.to
# Processing 5 / 35: 	 BIP-UN.to
# Processing 6 / 35: 	 BMO.to
# Processing 7 / 35: 	 BNS.to
# Processing 8 / 35: 	 CM.to
# Processing 9 / 35: 	 CNQ.to
# Processing 10 / 35: 	 CNR.to
# Processing 11 / 35: 	 CP.to
# Processing 12 / 35: 	 CSU.to
# Processing 13 / 35: 	 CVE.to
# Processing 14 / 35: 	 ENB.to
# Processing 15 / 35: 	 FNV.to
# Processing 16 / 35: 	 GWO.to
# Processing 17 / 35: 	 IMO.to
# Processing 18 / 35: 	 L.to
# Processing 19 / 35: 	 MFC.to
# Processing 20 / 35: 	 MG.to
# Processing 21 / 35: 	 NA.to
# Processing 22 / 35: 	 NGT.to
# Processing 23 / 35: 	 NTR.to
# Processing 24 / 35: 	 QSP-UN.to
# Processing 25 / 35: 	 RCI-A.to
# Processing 26 / 35: 	 RCI-B.to
# Processing 27 / 35: 	 RY.to
# Processing 28 / 35: 	 SLF.to
# Processing 29 / 35: 	 SU.to
# Processing 30 / 35: 	 Shop.to
# Processing 31 / 35: 	 T.to
# Processing 32 / 35: 	 TD.to
# Processing 33 / 35: 	 TRI.to
# Processing 34 / 35: 	 TRP.to
# Processing 35 / 35: 	 WCN.to
# Whole Dataset Generated with Shape of (14650, 163)
# FinTA.OBV_Normalized column .isnull().values.any()
# FinTA.Pct_change_400 column .isnull().values.any()
# Feature extraction elapsed time (seconds) :  55.26122212409973
# Xy.shape (416, 163)
# X_samples_for_prediction (348, 153)
#
#  2022.03.02-1514_Canada_All_30_3000B_20210101_to_20220228, 4_in_4days
# selected_meta_data.shape =  (35, 13)
# Finance                   10
# Communications             4
# Energy Minerals            4
# Non-Energy Minerals        3
# Technology Services        3
# Industrial Services        3
# Transportation             2
# Retail Trade               2
# Consumer Services          1
# Process Industries         1
# Producer Manufacturing     1
# Utilities                  1
# Name: Sector, dtype: int64
# Processing 1 / 35: 	 ABX.to
# Duplicated column names [] []
# Processing 2 / 35: 	 ATD.to
# Processing 3 / 35: 	 BAM-A.to
# Processing 4 / 35: 	 BCE.to
# Processing 5 / 35: 	 BIP-UN.to
# Processing 6 / 35: 	 BMO.to
# Processing 7 / 35: 	 BNS.to
# Processing 8 / 35: 	 CM.to
# Processing 9 / 35: 	 CNQ.to
# Processing 10 / 35: 	 CNR.to
# Processing 11 / 35: 	 CP.to
# Processing 12 / 35: 	 CSU.to
# Processing 13 / 35: 	 CVE.to
# Processing 14 / 35: 	 ENB.to
# Processing 15 / 35: 	 FNV.to
# Processing 16 / 35: 	 GWO.to
# Processing 17 / 35: 	 IMO.to
# Processing 18 / 35: 	 L.to
# Processing 19 / 35: 	 MFC.to
# Processing 20 / 35: 	 MG.to
# Processing 21 / 35: 	 NA.to
# Processing 22 / 35: 	 NGT.to
# Processing 23 / 35: 	 NTR.to
# Processing 24 / 35: 	 QSP-UN.to
# Processing 25 / 35: 	 RCI-A.to
# Processing 26 / 35: 	 RCI-B.to
# Processing 27 / 35: 	 RY.to
# Processing 28 / 35: 	 SLF.to
# Processing 29 / 35: 	 SU.to
# Processing 30 / 35: 	 Shop.to
# Processing 31 / 35: 	 T.to
# Processing 32 / 35: 	 TD.to
# Processing 33 / 35: 	 TRI.to
# Processing 34 / 35: 	 TRP.to
# Processing 35 / 35: 	 WCN.to
# Whole Dataset Generated with Shape of (14650, 163)
# FinTA.OBV_Normalized column .isnull().values.any()
# FinTA.Pct_change_400 column .isnull().values.any()
# Feature extraction elapsed time (seconds) :  53.703204870224
# Xy.shape (416, 163)
# X_samples_for_prediction (140, 153)
#
#  2022.03.02-1505_Canada_All_5_3000B_20210101_to_20220228, 4_in_4days
# selected_meta_data.shape =  (100, 13)
# Finance                   20
# Non-Energy Minerals       14
# Utilities                 10
# Technology Services        9
# Retail Trade               8
# Industrial Services        7
# Energy Minerals            7
# Communications             6
# Consumer Non-Durables      4
# Commercial Services        4
# Transportation             4
# Consumer Services          2
# Consumer Durables          1
# Distribution Services      1
# Process Industries         1
# Health Technology          1
# Producer Manufacturing     1
# Name: Sector, dtype: int64
# Processing 1 / 100: 	 ABX.to
# Duplicated column names [] []
# Processing 2 / 100: 	 AC.to
# Processing 3 / 100: 	 AEM.to
# Processing 4 / 100: 	 AQN.to
# Processing 5 / 100: 	 ARX.to
# Processing 6 / 100: 	 ATD.to
# Processing 7 / 100: 	 BAM-A.to
# Processing 8 / 100: 	 BCE.to
# Processing 9 / 100: 	 BEP-UN.to
# Processing 10 / 100: 	 BEPC.to
# Processing 11 / 100: 	 BHC.to
# Processing 12 / 100: 	 BIP-UN.to
# Processing 13 / 100: 	 BMO.to
# Processing 14 / 100: 	 BNS.to
# Processing 15 / 100: 	 CAE.to
# Processing 16 / 100: 	 CCL-A.to
# Processing 17 / 100: 	 CCL-B.to
# Processing 18 / 100: 	 CCO.to
# Processing 19 / 100: 	 CDAY.to
# Processing 20 / 100: 	 CIGI.to
# Processing 21 / 100: 	 CM.to
# Processing 22 / 100: 	 CNQ.to
# Processing 23 / 100: 	 CNR.to
# Processing 24 / 100: 	 CP.to
# Processing 25 / 100: 	 CSU.to
# Processing 26 / 100: 	 CTC-A.to
# Processing 27 / 100: 	 CTC.to
# Processing 28 / 100: 	 CU-X.to
# Processing 29 / 100: 	 CU.to
# Processing 30 / 100: 	 CVE.to
# Processing 31 / 100: 	 DOL.to
# Processing 32 / 100: 	 DOO.to
# Processing 33 / 100: 	 DSG.to
# Processing 34 / 100: 	 EMA.to
# Processing 35 / 100: 	 EMP-A.to
# Processing 36 / 100: 	 ENB.to
# Processing 37 / 100: 	 FFH-U.to
# Short history of ticker, Skip it !
# Processing 38 / 100: 	 FFH.to
# Processing 39 / 100: 	 FM.to
# Processing 40 / 100: 	 FNV.to
# Processing 41 / 100: 	 FSV.to
# Processing 42 / 100: 	 FTS.to
# Processing 43 / 100: 	 GFL.to
# Processing 44 / 100: 	 GIB-A.to
# Processing 45 / 100: 	 GIL.to
# Processing 46 / 100: 	 GLXY.to
# Processing 47 / 100: 	 GWO.to
# Processing 48 / 100: 	 H.to
# Processing 49 / 100: 	 IAG.to
# Processing 50 / 100: 	 IFC.to
# Processing 51 / 100: 	 IGM.to
# Processing 52 / 100: 	 IMO.to
# Processing 53 / 100: 	 IVN.to
# Processing 54 / 100: 	 K.to
# Processing 55 / 100: 	 KL.to
# Processing 56 / 100: 	 L.to
# Processing 57 / 100: 	 LSPD.to
# Processing 58 / 100: 	 MFC.to
# Processing 59 / 100: 	 MG.to
# Processing 60 / 100: 	 MRU.to
# Processing 61 / 100: 	 NA.to
# Processing 62 / 100: 	 NCM.to
# Processing 63 / 100: 	 NGT.to
# Processing 64 / 100: 	 NPI.to
# Processing 65 / 100: 	 NTR.to
# Processing 66 / 100: 	 NVEI.to
# Processing 67 / 100: 	 ONEX.to
# Processing 68 / 100: 	 OTEX.to
# Processing 69 / 100: 	 OVV.to
# Processing 70 / 100: 	 POW.to
# Processing 71 / 100: 	 PPL.to
# Processing 72 / 100: 	 QSP-UN.to
# Processing 73 / 100: 	 QSR.to
# Processing 74 / 100: 	 RBA.to
# Processing 75 / 100: 	 RCI-A.to
# Processing 76 / 100: 	 RCI-B.to
# Processing 77 / 100: 	 RY.to
# Processing 78 / 100: 	 SAP.to
# Processing 79 / 100: 	 SJR-B.to
# Processing 80 / 100: 	 SLF.to
# Processing 81 / 100: 	 STN.to
# Processing 82 / 100: 	 SU.to
# Processing 83 / 100: 	 Shop.to
# Processing 84 / 100: 	 T.to
# Processing 85 / 100: 	 TD.to
# Processing 86 / 100: 	 TECK-A.to
# Processing 87 / 100: 	 TECK-B.to
# Processing 88 / 100: 	 TFII.to
# Processing 89 / 100: 	 TIH.to
# Processing 90 / 100: 	 TIXT.to
# Processing 91 / 100: 	 TOU.to
# Processing 92 / 100: 	 TPX-A.to
# Processing 93 / 100: 	 TPX-B.to
# Processing 94 / 100: 	 TRI.to
# Processing 95 / 100: 	 TRP.to
# Processing 96 / 100: 	 WCN.to
# Processing 97 / 100: 	 WFG.to
# Processing 98 / 100: 	 WN.to
# Processing 99 / 100: 	 WPM.to
# Processing 100 / 100: 	 WSP.to
# Whole Dataset Generated with Shape of (40859, 163)
# FinTA.OBV_Normalized column .isnull().values.any()
# FinTA.Pct_change_400 column .isnull().values.any()
# Feature extraction elapsed time (seconds) :  149.66118168830872
# Xy.shape (1156, 163)
# X_samples_for_prediction (388, 153)
#
#  2022.03.02-1500_Canada_All_5_3000B_20210101_to_20220228, 7_in_14days
# selected_meta_data.shape =  (100, 13)
# Finance                   20
# Non-Energy Minerals       14
# Utilities                 10
# Technology Services        9
# Retail Trade               8
# Industrial Services        7
# Energy Minerals            7
# Communications             6
# Consumer Non-Durables      4
# Commercial Services        4
# Transportation             4
# Consumer Services          2
# Consumer Durables          1
# Distribution Services      1
# Process Industries         1
# Health Technology          1
# Producer Manufacturing     1
# Name: Sector, dtype: int64
# Processing 1 / 100: 	 ABX.to
# Duplicated column names [] []
# Processing 2 / 100: 	 AC.to
# Processing 3 / 100: 	 AEM.to
# Processing 4 / 100: 	 AQN.to
# Processing 5 / 100: 	 ARX.to
# Processing 6 / 100: 	 ATD.to
# Processing 7 / 100: 	 BAM-A.to
# Processing 8 / 100: 	 BCE.to
# Processing 9 / 100: 	 BEP-UN.to
# Processing 10 / 100: 	 BEPC.to
# Processing 11 / 100: 	 BHC.to
# Processing 12 / 100: 	 BIP-UN.to
# Processing 13 / 100: 	 BMO.to
# Processing 14 / 100: 	 BNS.to
# Processing 15 / 100: 	 CAE.to
# Processing 16 / 100: 	 CCL-A.to
# Processing 17 / 100: 	 CCL-B.to
# Processing 18 / 100: 	 CCO.to
# Processing 19 / 100: 	 CDAY.to
# Processing 20 / 100: 	 CIGI.to
# Processing 21 / 100: 	 CM.to
# Processing 22 / 100: 	 CNQ.to
# Processing 23 / 100: 	 CNR.to
# Processing 24 / 100: 	 CP.to
# Processing 25 / 100: 	 CSU.to
# Processing 26 / 100: 	 CTC-A.to
# Processing 27 / 100: 	 CTC.to
# Processing 28 / 100: 	 CU-X.to
# Processing 29 / 100: 	 CU.to
# Processing 30 / 100: 	 CVE.to
# Processing 31 / 100: 	 DOL.to
# Processing 32 / 100: 	 DOO.to
# Processing 33 / 100: 	 DSG.to
# Processing 34 / 100: 	 EMA.to
# Processing 35 / 100: 	 EMP-A.to
# Processing 36 / 100: 	 ENB.to
# Processing 37 / 100: 	 FFH-U.to
# Short history of ticker, Skip it !
# Processing 38 / 100: 	 FFH.to
# Processing 39 / 100: 	 FM.to
# Processing 40 / 100: 	 FNV.to
# Processing 41 / 100: 	 FSV.to
# Processing 42 / 100: 	 FTS.to
# Processing 43 / 100: 	 GFL.to
# Processing 44 / 100: 	 GIB-A.to
# Processing 45 / 100: 	 GIL.to
# Processing 46 / 100: 	 GLXY.to
# Processing 47 / 100: 	 GWO.to
# Processing 48 / 100: 	 H.to
# Processing 49 / 100: 	 IAG.to
# Processing 50 / 100: 	 IFC.to
# Processing 51 / 100: 	 IGM.to
# Processing 52 / 100: 	 IMO.to
# Processing 53 / 100: 	 IVN.to
# Processing 54 / 100: 	 K.to
# Processing 55 / 100: 	 KL.to
# Processing 56 / 100: 	 L.to
# Processing 57 / 100: 	 LSPD.to
# Processing 58 / 100: 	 MFC.to
# Processing 59 / 100: 	 MG.to
# Processing 60 / 100: 	 MRU.to
# Processing 61 / 100: 	 NA.to
# Processing 62 / 100: 	 NCM.to
# Processing 63 / 100: 	 NGT.to
# Processing 64 / 100: 	 NPI.to
# Processing 65 / 100: 	 NTR.to
# Processing 66 / 100: 	 NVEI.to
# Processing 67 / 100: 	 ONEX.to
# Processing 68 / 100: 	 OTEX.to
# Processing 69 / 100: 	 OVV.to
# Processing 70 / 100: 	 POW.to
# Processing 71 / 100: 	 PPL.to
# Processing 72 / 100: 	 QSP-UN.to
# Processing 73 / 100: 	 QSR.to
# Processing 74 / 100: 	 RBA.to
# Processing 75 / 100: 	 RCI-A.to
# Processing 76 / 100: 	 RCI-B.to
# Processing 77 / 100: 	 RY.to
# Processing 78 / 100: 	 SAP.to
# Processing 79 / 100: 	 SJR-B.to
# Processing 80 / 100: 	 SLF.to
# Processing 81 / 100: 	 STN.to
# Processing 82 / 100: 	 SU.to
# Processing 83 / 100: 	 Shop.to
# Processing 84 / 100: 	 T.to
# Processing 85 / 100: 	 TD.to
# Processing 86 / 100: 	 TECK-A.to
# Processing 87 / 100: 	 TECK-B.to
# Processing 88 / 100: 	 TFII.to
# Processing 89 / 100: 	 TIH.to
# Processing 90 / 100: 	 TIXT.to
# Processing 91 / 100: 	 TOU.to
# Processing 92 / 100: 	 TPX-A.to
# Processing 93 / 100: 	 TPX-B.to
# Processing 94 / 100: 	 TRI.to
# Processing 95 / 100: 	 TRP.to
# Processing 96 / 100: 	 WCN.to
# Processing 97 / 100: 	 WFG.to
# Processing 98 / 100: 	 WN.to
# Processing 99 / 100: 	 WPM.to
# Processing 100 / 100: 	 WSP.to
# Whole Dataset Generated with Shape of (40859, 163)
# FinTA.OBV_Normalized column .isnull().values.any()
# FinTA.Pct_change_400 column .isnull().values.any()
# Feature extraction elapsed time (seconds) :  158.8658790588379
# Xy.shape (1156, 163)
# X_samples_for_prediction (1156, 153)
# [0.224, 0.44, 0.583, 0.815, 0.391, 0.562, 0.407, 0.433, 0.378, 0.308, 0.211]
# Elapsed time (seconds) :  18.07665119568507

# %%
res2 = res[['Ticker', 'Date', 'Weighted Avg', 'Mean','Prod']]


def best_by_Weighted_Avg(df):
    top_candidates = []
    print(df.shape)
    n = 6
    cand1 = list(df.sort_values(by='Weighted Avg', ascending=False)['Ticker'].iloc[0:n])
    cand2 = list(df.sort_values(by='Mean', ascending=False)['Ticker'].iloc[0:n])
    cand3 = list(df.sort_values(by='Prod', ascending=False)['Ticker'].iloc[0:n])
    top_candidates = pd.Series([cand1, cand2, cand3])
    return top_candidates

d = pd.DataFrame(res2.groupby('Date').apply(best_by_Weighted_Avg), )
d.columns = ['Weighted Avg', 'Mean', 'Prod']
d
# Out:
# (97, 5)
# (97, 5)
# (95, 5)
# (95, 5)
# (96, 5)
# (96, 5)
# (97, 5)
# (96, 5)
# (97, 5)
# (97, 5)
# (96, 5)
# (97, 5)
#                                                  Weighted Avg  \
# Date
# 2022-03-08  [ABX.to, ATD.to, BAM-A.to, BCE.to, BMO.to, BNS...
# 2022-03-09  [ABX.to, ATD.to, BAM-A.to, BCE.to, BMO.to, BNS...
# 2022-03-10  [ABX.to, ATD.to, BAM-A.to, BCE.to, BMO.to, BNS...
# 2022-03-11  [ABX.to, ATD.to, BAM-A.to, BCE.to, BMO.to, BNS...
# 2022-03-14  [ABX.to, ATD.to, BAM-A.to, BCE.to, BMO.to, BNS...
# 2022-03-15  [ABX.to, ATD.to, BAM-A.to, BCE.to, BMO.to, BNS...
# 2022-03-16  [CCL-A.to, CTC.to, ABX.to, ATD.to, BAM-A.to, B...
# 2022-03-17  [ABX.to, AEM.to, AQN.to, ATD.to, BAM-A.to, BCE...
# 2022-03-18    [Shop.to, NGT.to, SU.to, ABX.to, CSU.to, CP.to]
# 2022-03-21  [Shop.to, CSU.to, ATD.to, TRI.to, BAM-A.to, AB...
# 2022-03-22  [CSU.to, Shop.to, ATD.to, SU.to, BAM-A.to, TRI...
# 2022-03-23  [Shop.to, CSU.to, ATD.to, TRI.to, BAM-A.to, SU...
#
#                                                          Mean  \
# Date
# 2022-03-08  [Shop.to, DOO.to, MG.to, TIXT.to, FSV.to, ONEX...
# 2022-03-09  [FSV.to, MG.to, Shop.to, GFL.to, BHC.to, CDAY.to]
# 2022-03-10  [Shop.to, CDAY.to, MG.to, TIXT.to, LSPD.to, FS...
# 2022-03-11  [LSPD.to, TIXT.to, Shop.to, CDAY.to, MG.to, FS...
# 2022-03-14  [LSPD.to, Shop.to, TIXT.to, CDAY.to, MG.to, GL...
# 2022-03-15  [TIXT.to, MG.to, GLXY.to, Shop.to, FSV.to, BHC...
# 2022-03-16  [CDAY.to, MG.to, CCL-B.to, CAE.to, Shop.to, BH...
# 2022-03-17  [MG.to, CDAY.to, CAE.to, TIXT.to, FSV.to, Shop...
# 2022-03-18  [TIXT.to, Shop.to, FSV.to, TOU.to, CCL-A.to, C...
# 2022-03-21  [CDAY.to, Shop.to, TIXT.to, MG.to, NVEI.to, ON...
# 2022-03-22  [TIXT.to, FSV.to, CDAY.to, GFL.to, GIL.to, CVE...
# 2022-03-23  [TIXT.to, CDAY.to, Shop.to, NVEI.to, CAE.to, L...
#
#                                                          Prod
# Date
# 2022-03-08  [DOO.to, ONEX.to, LSPD.to, AC.to, MG.to, CIGI.to]
# 2022-03-09  [LSPD.to, FSV.to, AC.to, DOO.to, ONEX.to, RBA.to]
# 2022-03-10  [LSPD.to, ONEX.to, GLXY.to, AC.to, STN.to, CIG...
# 2022-03-11  [LSPD.to, ONEX.to, GLXY.to, DOO.to, AC.to, STN...
# 2022-03-14  [LSPD.to, GLXY.to, ONEX.to, DOO.to, AC.to, STN...
# 2022-03-15  [GLXY.to, LSPD.to, ONEX.to, CIGI.to, AC.to, DS...
# 2022-03-16   [LSPD.to, DOO.to, GLXY.to, RBA.to, STN.to, K.to]
# 2022-03-17  [STN.to, GLXY.to, DOO.to, ONEX.to, LSPD.to, DS...
# 2022-03-18  [CIGI.to, K.to, RBA.to, BEPC.to, STN.to, ONEX.to]
# 2022-03-21  [ONEX.to, GLXY.to, DOO.to, RBA.to, CIGI.to, DS...
# 2022-03-22   [ONEX.to, ARX.to, K.to, RBA.to, STN.to, BEPC.to]
# 2022-03-23  [LSPD.to, ONEX.to, DOO.to, CIGI.to, DSG.to, K.to]

# %%
res2 = res[['Ticker', 'Date', 'Weighted Avg', 'Mean','Prod']]

def best_by_Weighted_Avg(df):
    top_candidates = []
    print(df.shape)
    cand1 = list(df.sort_values(by='Weighted Avg', ascending=False)['Ticker'].iloc[0:5])
    cand2 = list(df.sort_values(by='Mean', ascending=False)['Ticker'].iloc[0:5])
    cand3 = list(df.sort_values(by='Prod', ascending=False)['Ticker'].iloc[0:5])
    top_candidates = pd.Series([cand1, cand2, cand3])
    return top_candidates

d = pd.DataFrame(res2.groupby('Date').apply(best_by_Weighted_Avg), )
d.columns = ['Weighted Avg', 'Mean', 'Prod']
d
# Out:
# (80, 5)
# (79, 5)
#                                            Weighted Avg  \
# Date
# 2022-03-21  [Shop.to, CSU.to, ATD.to, TRI.to, BAM-A.to]
# 2022-03-22   [Shop.to, CSU.to, SU.to, BAM-A.to, TRI.to]
#
#                                                    Mean  \
# Date
# 2022-03-21  [CDAY.to, TIXT.to, Shop.to, NVEI.to, MG.to]
# 2022-03-22  [TIXT.to, CDAY.to, FSV.to, GFL.to, Shop.to]
#
#                                                      Prod
# Date
# 2022-03-21  [CDAY.to, TIXT.to, NVEI.to, CCL-A.to, BHC.to]
# 2022-03-22     [TIXT.to, CDAY.to, FSV.to, GFL.to, CAE.to]
