# %%
import os
import time
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xgboost as xgb
import shap

# %%
folder = r'Results/2022.02.01-1203_All_30_3000B_20210101_to_20220131, 5_in_5days/'
configs = json.load(open(folder + '/configs.json', 'r'))

# %%
model = xgb.Booster()  # init model
configs = json.load(open(folder + '/configs.json', 'r'))
model.load_model(folder + '/model_sklearn.json')  # load data

# %%
shap_values = pd.read_csv(folder + 'shap_values.csv').drop('Unnamed: 0', axis=1)
X = pd.read_csv(folder + 'shap_values_data.csv').drop('Unnamed: 0', axis=1)
shap_values.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-4b212b6ce2e8> in <module>
# ----> 1 shap_values = pd.read_csv(folder + 'shap_values.csv').drop('Unnamed: 0', axis=1)
#       2 X = pd.read_csv(folder + 'shap_values_data.csv').drop('Unnamed: 0', axis=1)
#       3 shap_values.shape
#
# ...

# %%
n = 100000
shap.summary_plot(shap_values.iloc[:n, :].values, X.iloc[:n, :])
