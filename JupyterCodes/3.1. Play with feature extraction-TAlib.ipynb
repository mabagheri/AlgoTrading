# %%
import time
import talib
import numpy as np
import pandas as pd
from talib.abstract import *


n = 50
close = np.random.randn(n)

inputs = pd.DataFrame({
    'open': np.random.random(n),
    'high': np.random.random(n),
    'low': np.random.random(n),
    'close': np.random.random(n),
    'volume': np.random.random(n)
})

# %%
# talib.get_functions()[:5]

# %%
# n_indicators = 0
# for item in talib.get_function_groups().items():
#     print(item, len(item[1]))
#     n_indicators += len(item[1])
# print("\n ***************** total n_indicators is:", n_indicators)

# %%
from talib.abstract import *

funcs = talib.get_functions()
funcs.remove('MAVP')
for func in funcs:
    res = eval(f'{func}(inputs)')
    if isinstance(res, pd.DataFrame):
        print(func, end='\t')
# Out:
# HT_PHASOR	HT_SINE	MINMAX	MINMAXINDEX	AROON	MACD	MACDEXT	MACDFIX	STOCH	STOCHF	STOCHRSI	BBANDS	MAMA

# %%
from talib.abstract import *

# uses close prices (default)
output = SMA(inputs, timeperiod=25)

# uses open prices
output = SMA(inputs, timeperiod=25, price='open')

# uses close prices (default)
# upper, middle, lower = BBANDS(inputs, 20, 2, 2)

# uses high, low, close (default)
slowk, slowd = STOCH(inputs, 5, 3, 0, 3, 0) # uses high, low, close by default

# uses high, low, open instead
slowk, slowd = STOCH(inputs, 5, 3, 0, 3, 0, prices=['high', 'low', 'open'])

# NATR(inputs)

# %%
data = inputs
from talib.abstract import *
d = {}
d["HT_DCPERIOD"] = HT_DCPERIOD(data, )
d["HT_DCPHASE"] = HT_DCPHASE(data, )
d["HT_PHASOR"] = HT_PHASOR(data, )
d["HT_SINE"] = HT_SINE(data, )
d["HT_TRENDMODE"] = HT_TRENDMODE(data, )
d["ADD"] = ADD(data, )
d["DIV"] = DIV(data, )
d["MAX"] = MAX(data, timeperiod=30)
d["MAXINDEX"] = MAXINDEX(data, timeperiod=30)
d["MIN"] = MIN(data, timeperiod=30)
d["MININDEX"] = MININDEX(data, timeperiod=30)
d["MINMAX"] = MINMAX(data, timeperiod=30)
d["MINMAXINDEX"] = MINMAXINDEX(data, timeperiod=30)
d["MULT"] = MULT(data, )
d["SUB"] = SUB(data, )
d["SUM"] = SUM(data, timeperiod=30)
d["ACOS"] = ACOS(data, )
d["ASIN"] = ASIN(data, )
d["ATAN"] = ATAN(data, )
d["CEIL"] = CEIL(data, )
d["COS"] = COS(data, )
d["COSH"] = COSH(data, )
d["EXP"] = EXP(data, )
d["FLOOR"] = FLOOR(data, )
d["LN"] = LN(data, )
d["LOG10"] = LOG10(data, )
d["SIN"] = SIN(data, )
d["SINH"] = SINH(data, )
d["SQRT"] = SQRT(data, )
d["TAN"] = TAN(data, )
d["TANH"] = TANH(data, )
d["ADX"] = ADX(data, timeperiod=14)
d["ADXR"] = ADXR(data, timeperiod=14)
d["APO"] = APO(data, fastperiod=12, slowperiod=26, matype=0)
d["AROON"] = AROON(data, timeperiod=14)
d["AROONOSC"] = AROONOSC(data, timeperiod=14)
d["BOP"] = BOP(data, )
d["CCI"] = CCI(data, timeperiod=14)
d["CMO"] = CMO(data, timeperiod=14)
d["DX"] = DX(data, timeperiod=14)
d["MACD"] = MACD(data, fastperiod=12, slowperiod=26, signalperiod=9)
d["MACDEXT"] = MACDEXT(data, fastperiod=12, fastmatype=0, slowperiod=26, slowmatype=0, signalperiod=9, signalmatype=0)
d["MACDFIX"] = MACDFIX(data, signalperiod=9)
d["MFI"] = MFI(data, timeperiod=14)
d["MINUS_DI"] = MINUS_DI(data, timeperiod=14)
d["MINUS_DM"] = MINUS_DM(data, timeperiod=14)
d["MOM"] = MOM(data, timeperiod=10)
d["PLUS_DI"] = PLUS_DI(data, timeperiod=14)
d["PLUS_DM"] = PLUS_DM(data, timeperiod=14)
d["PPO"] = PPO(data, fastperiod=12, slowperiod=26, matype=0)
d["ROC"] = ROC(data, timeperiod=10)
d["ROCP"] = ROCP(data, timeperiod=10)
d["ROCR"] = ROCR(data, timeperiod=10)
d["ROCR100"] = ROCR100(data, timeperiod=10)
d["RSI"] = RSI(data, timeperiod=14)
d["STOCH"] = STOCH(data, fastk_period=5, slowk_period=3, slowk_matype=0, slowd_period=3, slowd_matype=0)
d["STOCHF"] = STOCHF(data, fastk_period=5, fastd_period=3, fastd_matype=0)
d["STOCHRSI"] = STOCHRSI(data, timeperiod=14, fastk_period=5, fastd_period=3, fastd_matype=0)
d["TRIX"] = TRIX(data, timeperiod=30)
d["ULTOSC"] = ULTOSC(data, timeperiod1=7, timeperiod2=14, timeperiod3=28)
d["WILLR"] = WILLR(data, timeperiod=14)
d["BBANDS"] = BBANDS(data, timeperiod=5, nbdevup=2.0, nbdevdn=2.0, matype=0)
d["DEMA"] = DEMA(data, timeperiod=30)
d["EMA"] = EMA(data, timeperiod=30)
d["HT_TRENDLINE"] = HT_TRENDLINE(data, )
d["KAMA"] = KAMA(data, timeperiod=30)
d["MA"] = MA(data, timeperiod=30, matype=0)
d["MAMA"] = MAMA(data, fastlimit=0.5, slowlimit=0.05)
# d["MAVP"] = MAVP(data, minperiod=2, maxperiod=30, matype=0) data must be grouped in period for this to work
d["MIDPOINT"] = MIDPOINT(data, timeperiod=14)
d["MIDPRICE"] = MIDPRICE(data, timeperiod=14)
d["SAR"] = SAR(data, acceleration=0.02, maximum=0.2)
d["SAREXT"] = SAREXT(data, startvalue=0.0, offsetonreverse=0.0, accelerationinitlong=0.02, accelerationlong=0.02, accelerationmaxlong=0.2, accelerationinitshort=0.02, accelerationshort=0.02, accelerationmaxshort=0.2)
d["SMA"] = SMA(data, timeperiod=30)
d["T3"] = T3(data, timeperiod=5, vfactor=0.7)
d["TEMA"] = TEMA(data, timeperiod=30)
d["TRIMA"] = TRIMA(data, timeperiod=30)
d["WMA"] = WMA(data, timeperiod=30)
d["CDL2CROWS"] = CDL2CROWS(data, )
d["CDL3BLACKCROWS"] = CDL3BLACKCROWS(data, )
d["CDL3INSIDE"] = CDL3INSIDE(data, )
d["CDL3LINESTRIKE"] = CDL3LINESTRIKE(data, )
d["CDL3OUTSIDE"] = CDL3OUTSIDE(data, )
d["CDL3STARSINSOUTH"] = CDL3STARSINSOUTH(data, )
d["CDL3WHITESOLDIERS"] = CDL3WHITESOLDIERS(data, )
d["CDLABANDONEDBABY"] = CDLABANDONEDBABY(data, penetration=0.3)
d["CDLADVANCEBLOCK"] = CDLADVANCEBLOCK(data, )
d["CDLBELTHOLD"] = CDLBELTHOLD(data, )
d["CDLBREAKAWAY"] = CDLBREAKAWAY(data, )
d["CDLCLOSINGMARUBOZU"] = CDLCLOSINGMARUBOZU(data, )
d["CDLCONCEALBABYSWALL"] = CDLCONCEALBABYSWALL(data, )
d["CDLCOUNTERATTACK"] = CDLCOUNTERATTACK(data, )
d["CDLDARKCLOUDCOVER"] = CDLDARKCLOUDCOVER(data, penetration=0.5)
d["CDLDOJI"] = CDLDOJI(data, )
d["CDLDOJISTAR"] = CDLDOJISTAR(data, )
d["CDLDRAGONFLYDOJI"] = CDLDRAGONFLYDOJI(data, )
d["CDLENGULFING"] = CDLENGULFING(data, )
d["CDLEVENINGDOJISTAR"] = CDLEVENINGDOJISTAR(data, penetration=0.3)
d["CDLEVENINGSTAR"] = CDLEVENINGSTAR(data, penetration=0.3)
d["CDLGAPSIDESIDEWHITE"] = CDLGAPSIDESIDEWHITE(data, )
d["CDLGRAVESTONEDOJI"] = CDLGRAVESTONEDOJI(data, )
d["CDLHAMMER"] = CDLHAMMER(data, )
d["CDLHANGINGMAN"] = CDLHANGINGMAN(data, )
d["CDLHARAMI"] = CDLHARAMI(data, )
d["CDLHARAMICROSS"] = CDLHARAMICROSS(data, )
d["CDLHIGHWAVE"] = CDLHIGHWAVE(data, )
d["CDLHIKKAKE"] = CDLHIKKAKE(data, )
d["CDLHIKKAKEMOD"] = CDLHIKKAKEMOD(data, )
d["CDLHOMINGPIGEON"] = CDLHOMINGPIGEON(data, )
d["CDLIDENTICAL3CROWS"] = CDLIDENTICAL3CROWS(data, )
d["CDLINNECK"] = CDLINNECK(data, )
d["CDLINVERTEDHAMMER"] = CDLINVERTEDHAMMER(data, )
d["CDLKICKING"] = CDLKICKING(data, )
d["CDLKICKINGBYLENGTH"] = CDLKICKINGBYLENGTH(data, )
d["CDLLADDERBOTTOM"] = CDLLADDERBOTTOM(data, )
d["CDLLONGLEGGEDDOJI"] = CDLLONGLEGGEDDOJI(data, )
d["CDLLONGLINE"] = CDLLONGLINE(data, )
d["CDLMARUBOZU"] = CDLMARUBOZU(data, )
d["CDLMATCHINGLOW"] = CDLMATCHINGLOW(data, )
d["CDLMATHOLD"] = CDLMATHOLD(data, penetration=0.5)
d["CDLMORNINGDOJISTAR"] = CDLMORNINGDOJISTAR(data, penetration=0.3)
d["CDLMORNINGSTAR"] = CDLMORNINGSTAR(data, penetration=0.3)
d["CDLONNECK"] = CDLONNECK(data, )
d["CDLPIERCING"] = CDLPIERCING(data, )
d["CDLRICKSHAWMAN"] = CDLRICKSHAWMAN(data, )
d["CDLRISEFALL3METHODS"] = CDLRISEFALL3METHODS(data, )
d["CDLSEPARATINGLINES"] = CDLSEPARATINGLINES(data, )
d["CDLSHOOTINGSTAR"] = CDLSHOOTINGSTAR(data, )
d["CDLSHORTLINE"] = CDLSHORTLINE(data, )
d["CDLSPINNINGTOP"] = CDLSPINNINGTOP(data, )
d["CDLSTALLEDPATTERN"] = CDLSTALLEDPATTERN(data, )
d["CDLSTICKSANDWICH"] = CDLSTICKSANDWICH(data, )
d["CDLTAKURI"] = CDLTAKURI(data, )
d["CDLTASUKIGAP"] = CDLTASUKIGAP(data, )
d["CDLTHRUSTING"] = CDLTHRUSTING(data, )
d["CDLTRISTAR"] = CDLTRISTAR(data, )
d["CDLUNIQUE3RIVER"] = CDLUNIQUE3RIVER(data, )
d["CDLUPSIDEGAP2CROWS"] = CDLUPSIDEGAP2CROWS(data, )
d["CDLXSIDEGAP3METHODS"] = CDLXSIDEGAP3METHODS(data, )
d["AVGPRICE"] = AVGPRICE(data, )
d["MEDPRICE"] = MEDPRICE(data, )
d["TYPPRICE"] = TYPPRICE(data, )
d["WCLPRICE"] = WCLPRICE(data, )
d["BETA"] = BETA(data, timeperiod=5)
d["CORREL"] = CORREL(data, timeperiod=30)
d["LINEARREG"] = LINEARREG(data, timeperiod=14)
d["LINEARREG_ANGLE"] = LINEARREG_ANGLE(data, timeperiod=14)
d["LINEARREG_INTERCEPT"] = LINEARREG_INTERCEPT(data, timeperiod=14)
d["LINEARREG_SLOPE"] = LINEARREG_SLOPE(data, timeperiod=14)
d["STDDEV"] = STDDEV(data, timeperiod=5, nbdev=1.0)
d["TSF"] = TSF(data, timeperiod=14)
d["VAR"] = VAR(data, timeperiod=5, nbdev=1.0)
d["ATR"] = ATR(data, timeperiod=14)
d["NATR"] = NATR(data, timeperiod=14)
d["TRANGE"] = TRANGE(data, )
d["AD"] = AD(data, )
d["ADOSC"] = ADOSC(data, fastperiod=3, slowperiod=10)
d["OBV"] = OBV(data, )

# %%
features = data
for key in d.keys():
    if isinstance(d[key], pd.DataFrame):
        features = pd.concat([features, d[key]], axis=1)
    else:
        new_col = pd.Series(d[key], name=key)    
        features = pd.concat([features, new_col], axis=1)

# %% [markdown]
# ### Using TALib, check what features are Value (Price) dependent

# %%
data = pd.read_csv("../Data/Daily/US_Market/latest/AAPL_USD_20000101_to_20211220_daily_yahoo_finance.csv", 
                   parse_dates=True, index_col=0)
data = data.rename(columns={"Open": "open", 'Close': "close", "High": "high", "Low": "low", "Volume":"volume"})
print(data.shape)
data.head(3)

data2 = (data / 10).reset_index()
data = data.reset_index()#.drop('Date', axis=1)
# Out:
# (5528, 6)

# %%
indicators_TAlib_df = pd.read_csv\
    ("C:/Users/user/Dropbox/+Trading/AlgorithmicTrading/Backup/AlgoTrading_v2/core/feature_extraction/TAlib_indicators.csv")
indicators_TAlib = indicators_TAlib_df.values
indicators_TAlib[:3, :2]
indicators_TAlib_df.head(3)
# Out:
#                            Indicator  Symbol  \
# 0                    Bollinger Bands  BBANDS
# 1  Double Exponential Moving Average    DEMA
# 2         Exponential Moving Average     EMA
#
#                                            Jointed Value dependent  \
# 0                  ["Bollinger Bands" , "BBANDS"],             Yes
# 1  ["Double Exponential Moving Average" , "DEMA"],             Yes
# 2          ["Exponential Moving Average" , "EMA"],             Yes
#
#    Processing time
# 0         0.009996
# 1         0.002996
# 2         0.003999

# %%
# %%time
# Check if they are Value dependent
indicators_analysis = []
for indicator in indicators_TAlib[:]:
    st = time.time()
    res1 = eval(f"{indicator[1]}(data)")   # , *{args}
    res2 = eval(f"{indicator[1]}(data2)")  # , *{args}

    value_dependant = 'No' if (np.allclose(res1.values, res2.values,  atol=1e-2, equal_nan=True )) else 'Yes'
    
    elapsed_time = time.time() - st
    
    indicators_analysis.append([indicator[0], indicator[1], value_dependant, elapsed_time])

indicators_analysis = pd.DataFrame(indicators_analysis, columns=('Indicator', 'Symbol',"Value dependent", "Processing time"))
indicators_analysis.head(20)
# Out:
# Wall time: 290 ms
#                                       Indicator        Symbol Value dependent  \
# 0                               Bollinger Bands        BBANDS             Yes
# 1             Double Exponential Moving Average          DEMA             Yes
# 2                    Exponential Moving Average           EMA             Yes
# 3   Hilbert Transform - Instantaneous Trendline  HT_TRENDLINE             Yes
# 4               Kaufman Adaptive Moving Average          KAMA             Yes
# 5                                Moving average            MA             Yes
# 6                  MESA Adaptive Moving Average          MAMA             Yes
# 7                          MidPoint over period      MIDPOINT             Yes
# 8                    Midpoint Price over period      MIDPRICE             Yes
# 9                                 Parabolic SAR           SAR             Yes
# 10                     Parabolic SAR - Extended        SAREXT             Yes
# ...

# %%
# indicators_TAlib_df = pd.concat([indicators_TAlib_df, indicators_analysis[["Value dependent", "Processing time"]]], axis=1)
# indicators_TAlib_df.to_csv("C:/Users/user/Dropbox/+Trading/AlgorithmicTrading/AlgoTrading/core/feature_extraction/TAlib_indicators.csv", index=False)

# %%
price_independent_indicators = indicators_TAlib_df[indicators_TAlib_df['Value dependent']== 'No']
price_independent_indicators
# Out:
#                                      Indicator               Symbol  \
# 16          Average Directional Movement Index                  ADX
# 17   Average Directional Movement Index Rating                 ADXR
# 19                                       Aroon                AROON
# 20                            Aroon Oscillator             AROONOSC
# 21                            Balance Of Power                  BOP
# ..                                         ...                  ...
# 118                            Tristar Pattern           CDLTRISTAR
# 119                             Unique 3 River      CDLUNIQUE3RIVER
# 120                       Upside Gap Two Crows   CDLUPSIDEGAP2CROWS
# 121          Upside/Downside Gap Three Methods  CDLXSIDEGAP3METHODS
# 122                                       Beta                 BETA
#
#                                                Jointed Value dependent  \
# 16     ["Average Directional Movement Index" , "ADX"],              No
# ...

# %% [markdown]
# ### Find the default argument values

# %%
TALib_Indicators= [
  ["Average Directional Movement Index" , "ADX", ["(14, )", "(7, )", "(20, )", "(40, )", "(100, )", "(200, )"]],
  ["Average Directional Movement Index Rating" , "ADXR", ["(14, )"]],
  ["Aroon" , "AROON", ["(14, )", "(7, )", "(20, )", "(40, )", "(100, )", "(200, )"]],
  ["Aroon Oscillator" , "AROONOSC", ["(14, )"]],
  ["Balance Of Power" , "BOP", ["(1000, )"]],
  ["Commodity Channel Index" , "CCI", ["(14, )"]],
  ["Chande Momentum Oscillator" , "CMO", ["(14, )"]],
  ["Directional Movement Index" , "DX", ["(14, )"]],
  ["Minus Directional Indicator" , "MINUS_DI", ["(14, )"]],
  ["Plus Directional Indicator" , "PLUS_DI", ["(14, )"]],
  ["Percentage Price Oscillator" , "PPO", ["(12, 26, 0, )"]],
  ["Rate of change : ((price/prevPrice)-1)*100" , "ROC", ["(10, )"]],
  ["Rate of change Percentage: (price-prevPrice)/prevPrice" , "ROCP", ["(10, )"]],
  ["Rate of change ratio: (price/prevPrice)" , "ROCR", ["(10, )"]],
  ["Rate of change ratio 100 scale: (price/prevPrice)*100" , "ROCR100", ["(10, )"]],
  ["Relative Strength Index" , "RSI", ["(14, )"]],
  ["Stochastic" , "STOCH", ["(5, 3, 0, 3, 0)"]],
  ["Stochastic Fast" , "STOCHF", ["(5, 3, 0)"]],
  ["Stochastic Relative Strength Index" , "STOCHRSI", ["(14, 5, 3, 0, )"]],
  ["1-day Rate-Of-Change (ROC) of a Triple Smooth EMA" , "TRIX", ["(30, )"]],
  ["Ultimate Oscillator" , "ULTOSC", ["(7, 14, 28)"]],
  ["Williams' %R" , "WILLR", ["(14, )"]],
  ["Hilbert Transform - Dominant Cycle Period" , "HT_DCPERIOD", ["(999, )"]],
  ["Hilbert Transform - Dominant Cycle Phase" , "HT_DCPHASE", ["(999, )"]],
  ["Hilbert Transform - SineWave" , "HT_SINE", ["(999, )"]],
  ["Hilbert Transform - Trend vs Cycle Mode" , "HT_TRENDMODE", ["(999, )"]],
  ["Normalized Average True Range" , "NATR", ["(14, )", "(7, )", "(20, )", "(40, )", "(100, )", "(200, )"]],
  ["Two Crows" , "CDL2CROWS", ["(999, )"]],
  ["Three Black Crows" , "CDL3BLACKCROWS", ["(999, )"]],
  ["Three Inside Up/Down" , "CDL3INSIDE", ["(999, )"]],
  ["Three-Line Strike" , "CDL3LINESTRIKE", ["(999, )"]],
  ["Three Outside Up/Down" , "CDL3OUTSIDE", ["(999, )"]],
  ["Three Stars In The South" , "CDL3STARSINSOUTH", ["(999, )"]],
  ["Three Advancing White Soldiers" , "CDL3WHITESOLDIERS", ["(999, )"]],
  ["Abandoned Baby" , "CDLABANDONEDBABY", ["(0.999, )", ]],
  ["Advance Block" , "CDLADVANCEBLOCK", ["(999, )"]],
  ["Belt-hold" , "CDLBELTHOLD", ["(999, )"]],
  ["Breakaway" , "CDLBREAKAWAY", ["(999, )"]],
  ["Closing Marubozu" , "CDLCLOSINGMARUBOZU", ["(999, )"]],
  ["Concealing Baby Swallow" , "CDLCONCEALBABYSWALL", ["(999, )"]],
  ["Counterattack" , "CDLCOUNTERATTACK", ["(999, )"]],
  ["Dark Cloud Cover" , "CDLDARKCLOUDCOVER", ["(0.5, )"]],
  ["Doji" , "CDLDOJI", ["(999, )"]],
  ["Doji Star" , "CDLDOJISTAR", ["(999, )"]],
  ["Dragonfly Doji" , "CDLDRAGONFLYDOJI", ["(999, )"]],
  ["Engulfing Pattern" , "CDLENGULFING", ["(999, )"]],
  ["Evening Doji Star" , "CDLEVENINGDOJISTAR", ["(0.3, )"]],
  ["Evening Star" , "CDLEVENINGSTAR", ["(0.3, )"]],
  ["Up/Down-gap side-by-side white lines" , "CDLGAPSIDESIDEWHITE", ["(999, )"]],
  ["Gravestone Doji" , "CDLGRAVESTONEDOJI", ["(999, )"]],
  ["Hammer" , "CDLHAMMER", ["(999, )"]],
  ["Hanging Man" , "CDLHANGINGMAN", ["(999, )"]],
  ["Harami Pattern" , "CDLHARAMI", ["(999, )"]],
  ["Harami Cross Pattern" , "CDLHARAMICROSS", ["(999, )"]],
  ["Hikkake Pattern" , "CDLHIKKAKE", ["(999, )"]],
  ["Modified Hikkake Pattern" , "CDLHIKKAKEMOD", ["(999, )"]],
  ["Homing Pigeon" , "CDLHOMINGPIGEON", ["(999, )"]],
  ["Identical Three Crows" , "CDLIDENTICAL3CROWS", ["(999, )"]],
  ["In-Neck Pattern" , "CDLINNECK", ["(999, )"]],
  ["Inverted Hammer" , "CDLINVERTEDHAMMER", ["(999, )"]],
  ["Kicking" , "CDLKICKING", ["(999, )"]],
  ["Kicking - bull/bear determined by the longer marubozu" , "CDLKICKINGBYLENGTH", ["(999, )"]],
  ["Ladder Bottom" , "CDLLADDERBOTTOM", ["(999, )"]],
  ["Long Legged Doji" , "CDLLONGLEGGEDDOJI", ["(999, )"]],
  ["Long Line Candle" , "CDLLONGLINE", ["(999, )"]],
  ["Marubozu" , "CDLMARUBOZU", ["(999, )"]],
  ["Matching Low" , "CDLMATCHINGLOW", ["(999, )"]],
  ["Mat Hold" , "CDLMATHOLD", ["(0.999, )"]],
  ["Morning Doji Star" , "CDLMORNINGDOJISTAR", ["(0.999, )"]],
  ["Morning Star" , "CDLMORNINGSTAR", ["(0.3, )"]],
  ["On-Neck Pattern" , "CDLONNECK", ["(999, )"]],
  ["Piercing Pattern" , "CDLPIERCING", ["(999, )"]],
  ["Rickshaw Man" , "CDLRICKSHAWMAN", ["(999, )"]],
  ["Rising/Falling Three Methods" , "CDLRISEFALL3METHODS", ["(999, )"]],
  ["Separating Lines" , "CDLSEPARATINGLINES", ["(999, )"]],
  ["Shooting Star" , "CDLSHOOTINGSTAR", ["(999, )"]],
  ["Short Line Candle" , "CDLSHORTLINE", ["(999, )"]],
  ["Stalled Pattern" , "CDLSTALLEDPATTERN", ["(999, )"]],
  ["Stick Sandwich" , "CDLSTICKSANDWICH", ["(999, )"]],
  ["Takuri (Dragonfly Doji with very long lower shadow)" , "CDLTAKURI", ["(999, )"]],
  ["Tasuki Gap" , "CDLTASUKIGAP", ["(999, )"]],
  ["Thrusting Pattern" , "CDLTHRUSTING", ["(999, )"]],
  ["Tristar Pattern" , "CDLTRISTAR", ["(999, )"]],
  ["Unique 3 River" , "CDLUNIQUE3RIVER", ["(999, )"]],
  ["Upside Gap Two Crows" , "CDLUPSIDEGAP2CROWS", ["(999, )"]],
  ["Upside/Downside Gap Three Methods" , "CDLXSIDEGAP3METHODS", ["(999, )"]],
  ["Beta" , "BETA", ["(5, )", "(14, )", "(40, )", "(100, )"]]
]

# %%
indicators_analysis = []
for i, indicator in enumerate(TALib_Indicators[:]):
    # print(i, indicator)
    arg_me = indicator[2][0]

    res1 = eval(f"{indicator[1]}(data)")   
    res3 = eval(f"{indicator[1]}(data2, *{arg_me})") 
    my_arg_correct = 'Yes' if (np.allclose(res1.values, res3.values,  atol=1e-2, equal_nan=True )) else 'No'

    try:
        arg = '(0.65, )'
        res2 = eval(f"{indicator[1]}(data2, *{arg})") 
        have_args = 'No' if (np.allclose(res1.values, res2.values,  atol=1e-2, equal_nan=True )) else 'Yes'

    except:
        arg = '(1000, )'
        res2 = eval(f"{indicator[1]}(data2, *{arg})") 
        have_args = 'No' if (np.allclose(res1.values, res2.values,  atol=1e-2, equal_nan=True )) else 'Yes'
        
    default_arg = arg_me if have_args=='Yes' else 'NA'      
    indicators_analysis.append([indicator[0], indicator[1], have_args, default_arg, my_arg_correct])

indicators_analysis = pd.DataFrame(indicators_analysis, columns=('Indicator', 'Symbol',"Accept_args",\
                                                                 "Default_arg","Default_arg validated"))
mask = indicators_analysis['Default_arg']=='NA'
indicators_analysis['Default_arg validated'][mask] = 'NA'
# indicators_analysis.to_csv("Price_Independent_TAlib_Indicators.csv", index=False)
print(indicators_analysis.shape)
pd.set_option('display.max_rows', 100)
indicators_analysis.head(60) #[indicators_analysis['Accept_args']=='No'].head(60)
# Out:
# (87, 5)
#                                             Indicator               Symbol  \
# 0                  Average Directional Movement Index                  ADX
# 1           Average Directional Movement Index Rating                 ADXR
# 2                                               Aroon                AROON
# 3                                    Aroon Oscillator             AROONOSC
# 4                                    Balance Of Power                  BOP
# 5                             Commodity Channel Index                  CCI
# 6                          Chande Momentum Oscillator                  CMO
# 7                          Directional Movement Index                   DX
# 8                         Minus Directional Indicator             MINUS_DI
# 9                          Plus Directional Indicator              PLUS_DI
# 10                        Percentage Price Oscillator                  PPO
# ...

# %%
indicators_analysis.tail(30) #[indicators_analysis['Accept_args']=='No'].head(60)
# Out:
#                                             Indicator               Symbol  \
# 57                              Identical Three Crows   CDLIDENTICAL3CROWS
# 58                                    In-Neck Pattern            CDLINNECK
# 59                                    Inverted Hammer    CDLINVERTEDHAMMER
# 60                                            Kicking           CDLKICKING
# 61  Kicking - bull/bear determined by the longer m...   CDLKICKINGBYLENGTH
# 62                                      Ladder Bottom      CDLLADDERBOTTOM
# 63                                   Long Legged Doji    CDLLONGLEGGEDDOJI
# 64                                   Long Line Candle          CDLLONGLINE
# 65                                           Marubozu          CDLMARUBOZU
# 66                                       Matching Low       CDLMATCHINGLOW
# 67                                           Mat Hold           CDLMATHOLD
# ...
